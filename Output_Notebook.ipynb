# %%
from useful_functions import *

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import requests
import pandas as pd
import numpy as np

# %%
# List of favorited items kept on outside sheet
#favorite_items = list(pd.read_excel('Twisted_Bow_Tracker.xlsx', sheet_name='Favorite Items', header=0)['Name'])

# %%
# Create a 'top 20' table to check trends and margins
def top_20():
    df = generate_table(low=1.0E6, high=7.3E8).sort_values(by='true_margin', ascending=False)
    dat = df[df['quantity'] >= 10].head(20).reset_index(drop=True)
    return dat

# %%
import time
from IPython.display import clear_output
from IPython.display import display

# use this function to refresh the jupyter cell and keep up to date with API call
def periodic_work(interval):
    while True:
        #change this to the function you want to call, or paste in the code you want to run
        clear_output(wait=True)
        display(top_20())
        #interval should be an integer, the number of seconds to wait
        time.sleep(interval)

# %%
# periodic_work(10)
dat = top_20()
dat
# Out:
#                              name        buy       sell  true_margin  \
# 0                 Masori body (f)  242526000  248999999      3984000
# 1         Inquisitor's armour set  205300000  209820000      2421800
# 2                 Torva platebody  430270000  436510667      1875561
# 3                 Torva platelegs  393066780  398722000      1668000
# 4    Enhanced crystal weapon seed  152055000  155201375      1594362
# 5            Inquisitor's hauberk   67550000   69500000      1255000
# 6    Bow of faerdhinen (inactive)  155000000  157690000      1113100
# 7     Scythe of vitur (uncharged)  349558006  354208000      1107914
# 8              Ancestral robe top  130651111  133044000      1062449
# 9          Spectral spirit shield   56320492   57550000       654008
# 10                    Bandos hilt   17222000   17940558       539153
# 11  Sanguinesti staff (uncharged)   84632638   85999999       507362
# 12        Inquisitor's great helm   53247838   54222222       432162
# 13               Zaryte vambraces  197000000  199348888       355400
# 14               Ring of the gods   15487643   15888888       242357
# 15         Dragon hunter crossbow   61158199   61999996       221798
# 16    Uncharged toxic trident (e)    6596224    6874166       209201
# 17                 Staff of light    4576298    4818188       193709
# 18                 Rangers' tunic    3374005    3600000       189995
# 19                Masori mask (f)   47325000   47990354       185451
#
#     true_ROI(%)  quantity
# 0          1.64        20
# 1          1.18        23
# 2          0.44        16
# 3          0.42        13
# 4          1.05        11
# 5          1.86        13
# 6          0.72        22
# 7          0.32        24
# 8          0.81        41
# 9          1.16        12
# 10         3.13        10
# 11         0.60        38
# 12         0.81        13
# 13         0.18        27
# 14         1.56        13
# 15         0.36        62
# 16         3.17        16
# 17         4.23        14
# 18         5.63        21
# 19         0.39        26

# %%
# Generate panel for first item in the list
item = dat.loc[0,'name']
generate_panel(item)
# Out:
# alt.HConcatChart(...)

# %%
generate_table(item)
# Out:
#               name        buy       sell  true_margin  true_ROI(%)  quantity
# 0  Masori body (f)  242526000  248999999      3984000         1.64        20
